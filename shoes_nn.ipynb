# %%
import cv2
import glob
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn

# %matplotlib inline

# %%
data_path = '../data/edges2shoes/train/*.jpg'
img_paths = glob.glob(data_path)
len(img_paths)
# Out:
# 49825

# %%
plt.imshow(plt.imread(img_paths[0]))

# %% [markdown]
# ##### plt.imshow(plt.imread(img_paths[4]))
